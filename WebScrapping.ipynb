# %%
import requests
from bs4 import BeautifulSoup 

url="https://www.flipkart.com/search?q=camera&sid=jek%2Cp31%2Ctrv&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&as-pos=1&as-type=RECENT&suggestionId=camera%7CDSLR+%26+Mirrorless&requestId=6d676185-5e68-4323-9eca-52a599f4a659&as-searchtext=camera"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
response=requests.get(url,headers=headers)

htmlcontent=response.content
soup=BeautifulSoup(htmlcontent,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
print(soup.title)
print(soup.title.name)
print(soup.title.string)
print(soup.p)
print(soup.a)
# Out:
# <title>Camera- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>
# title
# Camera- Buy Products Online at Best Price in India - All Categories | Flipkart.com
# <p class="_2-N8zT">Great product</p>
# <a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /plus
# /account/login?ret=/search%3Fq%3Dcamera%26sid%3Djek%252Cp31%252Ctrv%26as%3Don%26as-show%3Don%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_6_na_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_6_na_na_na%26as-pos%3D1%26as-type%3DRECENT%26suggestionId%3Dcamera%257CDSLR%2B%2526%2BMirrorless%26requestId%3D6d676185-5e68-4323-9eca-52a599f4a659%26as-searchtext%3Dcamera
# https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect
# /viewcart?otracker=Cart_Icon_Click
# /cameras-accessories/pr?sid=jek&q=camera&otracker=categorytree
# /cameras/pr?sid=jek,p31&q=camera&otracker=categorytree
# /cameras/dslr-mirrorless/pr?sid=jek,p31,trv&q=camera&otracker=categorytree
# /buying-guide/dslr-camera?sid=jek,p31,trv&otracker=bg_from_browse_lhs
# /
# /cameras-accessories/pr?sid=jek&marketplace=FLIPKART
# /cameras/pr?sid=jek,p31&marketplace=FLIPKART
# /cameras/dslr-mirrorless/pr?sid=jek,p31,trv&marketplace=FLIPKART
# ...

# %%
for image in soup.find_all('img'):
    print(image.get('src'))
# Out:
# //static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_8d85f4.png
# //static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/plus_aef861.png
# //static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png
# //static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/buying-guide-illustration_4dd325.png
# https://rukminim1.flixcart.com/image/312/312/kw9krrk0/dslr-camera/6/j/k/-original-imag8z5wzzcgkzva.jpeg?q=70
# ...-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png
# https://rukminim1.flixcart.com/image/312/312/jfbfde80/camera/n/r/n/canon-eos-eos-3000d-dslr-original-imaf3t5h9yuyc5zu.jpeg?q=70
# ...-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png
# https://rukminim1.flixcart.com/image/312/312/kw9krrk0/dslr-camera/s/k/y/-original-imag8z5wgnmpqfvy.jpeg?q=70
# ...-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png
# ...

# %%
product=soup.find_all('div',class_="_3pLy-c row")
print(product)
# Out:
# [<div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">SONY Alpha ILCE-6400 Mirrorless Camera (Body Only)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTDLLFDJ5TNFYM4DZYV9KH5H_DLLFDJ5TNFYM4DZY_"><div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>402 Ratings </span><span class="_13vcmD">&amp;</span><span> 62 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">Effective Pixels: 24.2 MP</li><li class="rgWa7D">Sensor Type: CMOS</li><li class="rgWa7D">WiFi Available</li><li class="rgWa7D">NTSC/PAL</li><li class="rgWa7D">2 Year Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹70,990</div><div class="_3I9_wc _27UcVY">₹<!-- -->80,490</div><div class="_3Ay6Sb"><span>11% off</span></div></div><div class="_3tcB5a p8ucoS"><div><div class="_2Tpdn3" style="color:#000000;font-size:12p
# ...

# %%
productlist = soup.find_all('div',{'class':"_1AtVbE col-12-12"})
productlist
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/cameras-accessories/pr?sid=jek&amp;q=camera&amp;otracker=categorytree" title="Cameras &amp; Accessories">Cameras &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/cameras/pr?si
# ...

# %%
brand = []
for i in range(0,len(productlist)):
    brand.append(productlist[i].get_text().strip())
brand
# Out:
# ['FiltersCATEGORIESCameras & AccessoriesCamerasDSLR & MirrorlessPrice........Min₹5000₹10000₹15000₹20000₹30000₹50000to₹5000₹10000₹15000₹20000₹30000₹50000₹50000+?BrandCustomer Ratings4★ & above3★ & above2★ & above1★ & aboveOffersNo Cost EMISpecial PriceDiscountTypeMega PixelMaximum ISOSensor TypeGST Invoice AvailableMaximum Shutter SpeedVideo ResolutionColorFeaturesFPS in Burst ModeBattery TypeAvailability',
#  'Need help?Help me decide',
#  'SONY Alpha ILCE-6400 Mirrorless Camera (Body Only)4.7402 Ratings\xa0&\xa062 ReviewsEffective Pixels: 24.2 MPSensor Type: CMOSWiFi AvailableNTSC/PAL2 Year Warranty₹70,990₹80,49011% offFree delivery',
# ...

# %%
price = soup.find_all('div',class_='_30jeq3 _1_WHN1')
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹70,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹31,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,73,290</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹90,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹57,890</div>,
#  <div class="_30jeq3 _1_WHN1">₹56,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹89,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹2,24,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹56,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹2,42,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,83,690</div>,
#  <div class="_30jeq3 _1_WHN1">₹396</div>,
#  <div class="_30jeq3 _1_WHN1">₹2,96,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹85,995</div>,
#  <div class="_30jeq3 _1_WHN1">₹73,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹398</div>,
#  <div class="_30jeq3 _1_WHN1">₹89,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹74,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹92,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹328</div>,
# ...

# %%
product_price = []
for i in range(0,len(price)):
    product_price.append(price[i].get_text().strip())
product_price
# Out:
# ['₹70,990',
#  '₹31,999',
#  '₹1,73,290',
#  '₹38,999',
#  '₹90,999',
#  '₹57,890',
#  '₹56,499',
#  '₹89,999',
#  '₹2,24,990',
#  '₹56,990',
#  '₹2,42,990',
#  '₹1,83,690',
#  '₹396',
#  '₹2,96,990',
#  '₹85,995',
#  '₹73,999',
#  '₹398',
#  '₹89,999',
#  '₹74,499',
#  '₹92,999',
#  '₹328',
#  '₹3,29,995',
#  '₹99,356',
#  '₹1,39,499',
#  '₹1,57,999',
#  '₹86,995',
#  '₹1,48,608',
#  '₹341',
#  '₹94,950',
#  '₹1,71,999',
#  '₹1,00,999',
#  '₹1,43,999',
#  '₹90,284',
#  '₹328',
#  '₹1,64,995',
#  '₹2,36,499',
#  '₹1,85,999',
#  '₹1,21,990',
#  '₹1,74,999',
#  '₹1,32,990']

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /plus
# /account/login?ret=/search%3Fq%3Dcamera%26sid%3Djek%252Cp31%252Ctrv%26as%3Don%26as-show%3Don%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_6_na_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_6_na_na_na%26as-pos%3D1%26as-type%3DRECENT%26suggestionId%3Dcamera%257CDSLR%2B%2526%2BMirrorless%26requestId%3D6d676185-5e68-4323-9eca-52a599f4a659%26as-searchtext%3Dcamera
# https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect
# /viewcart?otracker=Cart_Icon_Click
# /cameras-accessories/pr?sid=jek&q=camera&otracker=categorytree
# /cameras/pr?sid=jek,p31&q=camera&otracker=categorytree
# /cameras/dslr-mirrorless/pr?sid=jek,p31,trv&q=camera&otracker=categorytree
# /buying-guide/dslr-camera?sid=jek,p31,trv&otracker=bg_from_browse_lhs
# /
# /cameras-accessories/pr?sid=jek&marketplace=FLIPKART
# /cameras/pr?sid=jek,p31&marketplace=FLIPKART
# /cameras/dslr-mirrorless/pr?sid=jek,p31,trv&marketplace=FLIPKART
# ...
